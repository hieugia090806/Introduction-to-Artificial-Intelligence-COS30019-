# %%
#--Import curcial libraries. --#
import os
import re
import pandas as pd

# %%
input_file = '../Raw/SCATSiteNumbers.csv'
output_dir = '../Processed'

# %%
df = pd.read_csv(input_file, sep='\t', skiprows=9)
df.columns = df.columns.str.strip()

# %%
if 'Site Type' in df.columns:
    unique_types = df['Site Type'].dropna().unique()
    
    print(f"Found {len(unique_types)} types. Exporting to '{output_dir}'...")

    for s_type in unique_types:
        filtered_df = df[df['Site Type'] == s_type]
        
        clean_label = "".join(word.capitalize() for word in re.sub(r'[^a-zA-Z0-9]', ' ', str(s_type)).split())
        file_name = f"SCATSType{clean_label}.csv"
        
        save_path = os.path.join(output_dir, file_name)
        
        filtered_df.to_csv(save_path, index=False)
        print(f"Successfully saved: {save_path}")
else:
    print("Error: 'Site Type' column not found. Please check your CSV header.")

print("\n--- PROCESSING COMPLETE ---")
# Out:
# Found 11 types. Exporting to '../Processed'...
# Successfully saved: ../Processed\SCATSTypeInt.csv
# Successfully saved: ../Processed\SCATSTypePos.csv
# Successfully saved: ../Processed\SCATSTypeFlashPx.csv
# Successfully saved: ../Processed\SCATSTypeFireWW.csv
# Successfully saved: ../Processed\SCATSTypeRbtMtr.csv
# Successfully saved: ../Processed\SCATSTypeFireSig.csv
# Successfully saved: ../Processed\SCATSTypeAmbuSig.csv
# Successfully saved: ../Processed\SCATSTypeRampMtr.csv
# Successfully saved: ../Processed\SCATSTypeBusSig.csv
# Successfully saved: ../Processed\SCATSTypeTmpPos.csv
# Successfully saved: ../Processed\SCATSTypeOHLane.csv
#
# --- PROCESSING COMPLETE ---
